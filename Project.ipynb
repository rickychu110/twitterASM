# %% [markdown]
# # Junior Data Engineer Programme - Interim Project     (28/10/2021)
#
# ### Projeect detail: https://docs.google.com/document/d/1Fsb5qMJQiAHVgEoYFJSK48uetxMak956jIP0pcprSpw/mobilebasic

# %% [markdown]
# ![CRAWL-TWITTER.png](attachment:0110a544-2f8a-4cb4-9aff-f30c2791a539.png)

# %% [markdown]
# # Twitter data crawler

# %% [markdown]
# ______________________________________

# %% [markdown]
# ## Phase 1: Data collection  (4-5 days)

# %% [markdown]
# ## Collect:
#
# ###   1. @JoeBiden's profile   tweepy user
# #### --> e.g. user = api.get_user(screen_name = name)
# #####
# ###   2. @JoeBiden's social network information  (a)
# #### --> e.g. for i, friend in enumerate(api.get_friends(screen_name=name)):
# #### --> e.g. status = api.user_timeline(screen_name=name)
# #### --> e.g. other tweets that mentions about him
# #### --> e.g. searched_tweets =
#         result = []
#         for status in tweepy.Cursor(api.search_tweets, q=search).items(1000):
#             result.append(status)
# ####
# ###   3. tweets with keywords: ['Coronavirus', 'Vaccination']
# #### --> e.g. searched_tweets =
#         result = []
#         for status in tweepy.Cursor(api.search_tweets, q=search).items(1000):
#             result.append(status)

# %% [markdown]
# __________________________________________________________

# %% [markdown]
# # Library maybe helpful:

# %% [markdown]
# ![擷取.PNG](attachment:11520000-ecd6-4764-b14c-13005385514a.PNG)

# %% [markdown]
# ## Tweepy:

# %% [markdown]
# ### Doc file https://docs.tweepy.org/en/v4.1.0/getting_started.html

# %% [markdown]
# #### 中 https://www.cnblogs.com/zhuminghui/p/12918272.html

# %% [markdown]
# ####     Tutorial on using Twitter API: https://www.youtube.com/watch?v=o_OZdbCzHUA   total:    6:52

# %% [markdown]
# #### Tutorial on  Tweet Visualization and Sentiment Analysis in Python https://www.youtube.com/watch?v=1gQ6uG5Ujiw  total:     1:30:01

# %% [markdown]
# _______________________________

# %% [markdown]
# # Phase 2: Import Data to SQL (8-9 days)

# %% [markdown]
# ### SQL: SQLite3

# %% [markdown]
# ## Task: tweets with keywords: [Coronavirus, Vaccination].

# %% [markdown]
# #### Tutorial on Store Tweets using Python 3:   https://medium.com/analytics-vidhya/scape-and-save-tweet-using-python-3-5a186777c388

# %% [markdown]
# #### Step by Step: Twitter Sentiment Analysis in Python https://towardsdatascience.com/step-by-step-twitter-sentiment-analysis-in-python-d6f650ade58d

# %% [markdown]
# # https://www.coder.work/article/89938

# %% [markdown]
# _____________________________________________________

# %% [markdown]
# # Phase 3: Flow

# %% [markdown]
# ### 1. Python crawler + Tweepy --> Pandas --> SQL (database + SQL GUI result ? ) --> 未諗到

# %% [markdown]
# ### OR

# %% [markdown]
# ### 2. Python crawler + Tweepy --> SQL python module --> SQL (database + SQL GUI result ? ) --> 未諗到

# %% [markdown]
# __________________________

# %% [markdown]
# # Creative element:

# %% [markdown]
# ### 1. GUI
